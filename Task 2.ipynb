# %%
import pandas as pd

# %%
df=pd.read_csv('iris.csv')

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# Checking the number of null values

# %%
df.isnull().sum()
# Out:
# sepal.length    0
# sepal.width     0
# petal.length    0
# petal.width     0
# variety         0
# dtype: int64

# %% [markdown]
# Printing the number of each type of flower

# %%
for i in df['variety'].value_counts():
    print(i,end =' ')
# Out:
# 50 50 50

# %% [markdown]
# Printing the data of the flower 'Iris-Virginica',where petal-length>1.5

# %%
df[(df['variety']=="Virginica")&(df["petal.length"]>1.5)]
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 100           6.3          3.3           6.0          2.5  Virginica
# 101           5.8          2.7           5.1          1.9  Virginica
# 102           7.1          3.0           5.9          2.1  Virginica
# 103           6.3          2.9           5.6          1.8  Virginica
# 104           6.5          3.0           5.8          2.2  Virginica
# 105           7.6          3.0           6.6          2.1  Virginica
# 106           4.9          2.5           4.5          1.7  Virginica
# 107           7.3          2.9           6.3          1.8  Virginica
# 108           6.7          2.5           5.8          1.8  Virginica
# 109           7.2          3.6           6.1          2.5  Virginica
# 110           6.5          3.2           5.1          2.0  Virginica
# 111           6.4          2.7           5.3          1.9  Virginica
# 112           6.8          3.0           5.5          2.1  Virginica
# ...

# %% [markdown]
# Printing the minimum,maximum and average value of the feature for each kind of flower

# %%
print(df[df.variety=="Setosa"].min())
print(df[df.variety=="Setosa"].max())
print(df[df.variety=="Setosa"].mean())
# Out:
# sepal.length       4.3
# sepal.width        2.3
# petal.length         1
# petal.width        0.1
# variety         Setosa
# dtype: object
# sepal.length       5.8
# sepal.width        4.4
# petal.length       1.9
# petal.width        0.6
# variety         Setosa
# dtype: object
# sepal.length    5.006
# sepal.width     3.428
# petal.length    1.462
# petal.width     0.246
# dtype: float64

# %%
print(df[df.variety=="Versicolor"].min())
print(df[df.variety=="Versicolor"].max())
print(df[df.variety=="Versicolor"].mean())
# Out:
# sepal.length           4.9
# sepal.width              2
# petal.length             3
# petal.width              1
# variety         Versicolor
# dtype: object
# sepal.length             7
# sepal.width            3.4
# petal.length           5.1
# petal.width            1.8
# variety         Versicolor
# dtype: object
# sepal.length    5.936
# sepal.width     2.770
# petal.length    4.260
# petal.width     1.326
# dtype: float64

# %%
print(df[df.variety=="Virginica"].min())
print(df[df.variety=="Virginica"].max())
print(df[df.variety=="Virginica"].mean())
# Out:
# sepal.length          4.9
# sepal.width           2.2
# petal.length          4.5
# petal.width           1.4
# variety         Virginica
# dtype: object
# sepal.length          7.9
# sepal.width           3.8
# petal.length          6.9
# petal.width           2.5
# variety         Virginica
# dtype: object
# sepal.length    6.588
# sepal.width     2.974
# petal.length    5.552
# petal.width     2.026
# dtype: float64

# %%
df1=pd.read_csv('terrorismData.csv')

# %%
df1.head()
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   Latitude   Longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target Summary  \
# ...

# %%
df1.drop(df1[df1["Day"]==0].index,inplace=True)
df1.drop(df1[df1["Month"]==0].index,inplace=True)

# %%
ct = df1['Country'].value_counts()
mc = ct.index[0]
mt = ct.values[0]
yt = df1[df1['Country'] == mc]['Year'].value_counts()
my = yt.index[0]
mty = yt.values[0]
print(mc," ",mt," ",mty)
# Out:
# Iraq   24616   3933
